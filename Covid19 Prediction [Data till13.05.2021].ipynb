# %%
import pandas as pd

# %%
covid=pd.read_csv("owid-covid-data.csv")

# %%
covid
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 89021      ZWE    Africa     Zimbabwe  2021-05-09      38419.0        5.0
# 89022      ZWE    Africa     Zimbabwe  2021-05-10      38433.0       14.0
# 89023      ZWE    Africa     Zimbabwe  2021-05-11      38448.0       15.0
# 89024      ZWE    Africa     Zimbabwe  2021-05-12      38466.0       18.0
# 89025      ZWE    Africa     Zimbabwe  2021-05-13      38491.0       25.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 89021              19.714        1576.0         0.0                0.857  ...
# 89022              20.000        1576.0         0.0                0.429  ...
# 89023              17.286        1579.0         3.0                0.714  ...
# 89024              15.571        1579.0         0.0                0.714  ...
# 89025              13.286        1582.0         3.0                1.000  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 89021        1899.775             21.4                307.846
# 89022        1899.775             21.4                307.846
# 89023        1899.775             21.4                307.846
# 89024        1899.775             21.4                307.846
# 89025        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 89021                 1.82             1.6          30.7
# 89022                 1.82             1.6          30.7
# 89023                 1.82             1.6          30.7
# 89024                 1.82             1.6          30.7
# 89025                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 89021                  36.791                         1.7            61.49
# 89022                  36.791                         1.7            61.49
# 89023                  36.791                         1.7            61.49
# 89024                  36.791                         1.7            61.49
# 89025                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 89021                    0.571
# 89022                    0.571
# 89023                    0.571
# 89024                    0.571
# 89025                    0.571
#
# [89026 rows x 59 columns]

# %%
covid.shape
# Out:
# (89026, 59)

# %%
covid.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
covid["location"].value_counts()
# Out:
# Mexico       499
# Argentina    499
# Thailand     496
# Peru         494
# Taiwan       484
#             ...
# Curacao       46
# Aruba         46
# Nauru         23
# Tonga         22
# Tuvalu         1
# Name: location, Length: 227, dtype: int64

# %%
covid.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  8.565900e+04   85657.000000        84656.000000  7.589600e+04
# mean   8.762032e+05    5987.102432         5979.191714  2.404947e+04
# std    6.046796e+06   37719.533828        37168.087393  1.425387e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    9.970000e+02       2.000000            7.143000  4.700000e+01
# 50%    1.115400e+04      71.000000           88.143000  3.280000e+02
# 75%    1.181745e+05     783.000000          815.714000  3.187000e+03
# max    1.611761e+08  905992.000000       826374.286000  3.344394e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  76054.000000         84656.000000             85197.000000
# mean     141.248915           125.483525             10720.443062
# std      772.094342           708.705298             20378.358953
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000               212.378000
# 50%        2.000000             1.286000              1459.378000
# 75%       18.000000            14.000000             10524.687000
# max    17906.000000         14435.857000            174335.081000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           85195.000000                    84199.000000
# mean               75.520238                       75.489659
# std               191.066010                      151.285667
# min             -2153.437000                     -276.825000
# 25%                 0.197000                        1.197000
# 50%                 7.849000                       10.351000
# 75%                69.890000                       78.114500
# max             18293.675000                     4083.500000
#
#        total_deaths_per_million  ...  gdp_per_capita  extreme_poverty  \
# count              75447.000000  ...    79864.000000     54104.000000
# mean                 236.976252  ...    19295.473362        13.359192
# std                  414.634591  ...    19941.057015        19.946220
# min                    0.001000  ...      661.240000         0.100000
# 25%                    7.011000  ...     4466.507000         0.500000
# 50%                   42.419000  ...    12951.839000         2.200000
# 75%                  256.685000  ...    27216.445000        21.200000
# max                 2998.856000  ...   116935.600000        77.600000
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# count           80106.000000         81859.000000    62740.000000
# mean              257.916902             7.867525       10.531059
# std               118.808063             4.047895       10.413955
# min                79.370000             0.990000        0.100000
# 25%               167.295000             5.310000        1.900000
# 50%               242.648000             7.110000        6.300000
# 75%               329.635000            10.080000       19.300000
# max               724.417000            30.530000       44.000000
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# count  61817.000000            40242.000000                73071.000000
# mean      32.663566               50.896414                    3.029625
# std       13.473303               31.762144                    2.462325
# min        7.700000                1.188000                    0.100000
# 25%       21.600000               20.859000                    1.300000
# 50%       31.400000               49.839000                    2.400000
# 75%       41.100000               83.241000                    3.861000
# max       78.100000               98.999000                   13.800000
#
#        life_expectancy  human_development_index
# count     84052.000000             80289.000000
# mean         73.224414                 0.727918
# std           7.564266                 0.150413
# min          53.280000                 0.394000
# 25%          67.920000                 0.602000
# 50%          74.620000                 0.748000
# 75%          78.740000                 0.848000
# max          86.750000                 0.957000
#
# [8 rows x 54 columns]

# %%
covid.isna().any()
# Out:
# iso_code                                 False
# continent                                 True
# location                                 False
# date                                     False
# total_cases                               True
# new_cases                                 True
# new_cases_smoothed                        True
# total_deaths                              True
# new_deaths                                True
# new_deaths_smoothed                       True
# total_cases_per_million                   True
# new_cases_per_million                     True
# new_cases_smoothed_per_million            True
# total_deaths_per_million                  True
# new_deaths_per_million                    True
# new_deaths_smoothed_per_million           True
# reproduction_rate                         True
# icu_patients                              True
# icu_patients_per_million                  True
# hosp_patients                             True
# hosp_patients_per_million                 True
# weekly_icu_admissions                     True
# weekly_icu_admissions_per_million         True
# weekly_hosp_admissions                    True
# weekly_hosp_admissions_per_million        True
# new_tests                                 True
# total_tests                               True
# total_tests_per_thousand                  True
# new_tests_per_thousand                    True
# new_tests_smoothed                        True
# new_tests_smoothed_per_thousand           True
# positive_rate                             True
# tests_per_case                            True
# tests_units                               True
# total_vaccinations                        True
# people_vaccinated                         True
# people_fully_vaccinated                   True
# new_vaccinations                          True
# new_vaccinations_smoothed                 True
# total_vaccinations_per_hundred            True
# people_vaccinated_per_hundred             True
# people_fully_vaccinated_per_hundred       True
# new_vaccinations_smoothed_per_million     True
# stringency_index                          True
# population                                True
# population_density                        True
# median_age                                True
# aged_65_older                             True
# aged_70_older                             True
# gdp_per_capita                            True
# extreme_poverty                           True
# cardiovasc_death_rate                     True
# diabetes_prevalence                       True
# female_smokers                            True
# male_smokers                              True
# handwashing_facilities                    True
# hospital_beds_per_thousand                True
# life_expectancy                           True
# human_development_index                   True
# dtype: bool

# %%
covid.isna().sum()
# Out:
# iso_code                                     0
# continent                                 4748
# location                                     0
# date                                         0
# total_cases                               3367
# new_cases                                 3369
# new_cases_smoothed                        4370
# total_deaths                             13130
# new_deaths                               12972
# new_deaths_smoothed                       4370
# total_cases_per_million                   3829
# new_cases_per_million                     3831
# new_cases_smoothed_per_million            4827
# total_deaths_per_million                 13579
# new_deaths_per_million                   13421
# new_deaths_smoothed_per_million           4827
# reproduction_rate                        17900
# icu_patients                             80017
# icu_patients_per_million                 80017
# hosp_patients                            77805
# hosp_patients_per_million                77805
# weekly_icu_admissions                    88210
# weekly_icu_admissions_per_million        88210
# weekly_hosp_admissions                   87611
# weekly_hosp_admissions_per_million       87611
# new_tests                                48752
# total_tests                              49064
# total_tests_per_thousand                 49064
# new_tests_per_thousand                   48752
# new_tests_smoothed                       42450
# new_tests_smoothed_per_thousand          42450
# positive_rate                            45648
# tests_per_case                           46242
# tests_units                              40965
# total_vaccinations                       77678
# people_vaccinated                        78403
# people_fully_vaccinated                  80970
# new_vaccinations                         79362
# new_vaccinations_smoothed                70648
# total_vaccinations_per_hundred           77678
# people_vaccinated_per_hundred            78403
# people_fully_vaccinated_per_hundred      80970
# new_vaccinations_smoothed_per_million    70648
# stringency_index                         13946
# population                                 580
# population_density                        6623
# median_age                                9349
# aged_65_older                            10251
# aged_70_older                             9792
# gdp_per_capita                            9162
# extreme_poverty                          34922
# cardiovasc_death_rate                     8920
# diabetes_prevalence                       7167
# female_smokers                           26286
# male_smokers                             27209
# handwashing_facilities                   48784
# hospital_beds_per_thousand               15955
# life_expectancy                           4974
# human_development_index                   8737
# dtype: int64

# %%
india_case=covid[covid["location"]=="India"]

# %%
india_case
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 36785      IND      Asia    India  2020-01-30          1.0        1.0
# 36786      IND      Asia    India  2020-01-31          1.0        0.0
# 36787      IND      Asia    India  2020-02-01          1.0        0.0
# 36788      IND      Asia    India  2020-02-02          2.0        1.0
# 36789      IND      Asia    India  2020-02-03          3.0        1.0
# ...        ...       ...      ...         ...          ...        ...
# 37250      IND      Asia    India  2021-05-09   22662575.0   366494.0
# 37251      IND      Asia    India  2021-05-10   22992517.0   329942.0
# 37252      IND      Asia    India  2021-05-11   23340938.0   348421.0
# 37253      IND      Asia    India  2021-05-12   23703665.0   362727.0
# 37254      IND      Asia    India  2021-05-13   24046809.0   343144.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 36785                 NaN           NaN         NaN                  NaN  ...
# 36786                 NaN           NaN         NaN                  NaN  ...
# 36787                 NaN           NaN         NaN                  NaN  ...
# 36788                 NaN           NaN         NaN                  NaN  ...
# 36789                 NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 37250          391008.286      246116.0      3769.0             3879.571  ...
# 37251          387097.714      249992.0      3876.0             3940.571  ...
# 37252          382279.857      254197.0      4205.0             4001.286  ...
# 37253          375179.286      258317.0      4120.0             4021.286  ...
# 37254          365030.143      262317.0      4000.0             4033.429  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 36785        6426.674             21.2                 282.28
# 36786        6426.674             21.2                 282.28
# 36787        6426.674             21.2                 282.28
# 36788        6426.674             21.2                 282.28
# 36789        6426.674             21.2                 282.28
# ...               ...              ...                    ...
# 37250        6426.674             21.2                 282.28
# 37251        6426.674             21.2                 282.28
# 37252        6426.674             21.2                 282.28
# 37253        6426.674             21.2                 282.28
# 37254        6426.674             21.2                 282.28
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 36785                10.39             1.9          20.6
# 36786                10.39             1.9          20.6
# 36787                10.39             1.9          20.6
# 36788                10.39             1.9          20.6
# 36789                10.39             1.9          20.6
# ...                    ...             ...           ...
# 37250                10.39             1.9          20.6
# 37251                10.39             1.9          20.6
# 37252                10.39             1.9          20.6
# 37253                10.39             1.9          20.6
# 37254                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 36785                   59.55                        0.53            69.66
# 36786                   59.55                        0.53            69.66
# 36787                   59.55                        0.53            69.66
# 36788                   59.55                        0.53            69.66
# 36789                   59.55                        0.53            69.66
# ...                       ...                         ...              ...
# 37250                   59.55                        0.53            69.66
# 37251                   59.55                        0.53            69.66
# 37252                   59.55                        0.53            69.66
# 37253                   59.55                        0.53            69.66
# 37254                   59.55                        0.53            69.66
#
#        human_development_index
# 36785                    0.645
# 36786                    0.645
# 36787                    0.645
# 36788                    0.645
# 36789                    0.645
# ...                        ...
# 37250                    0.645
# 37251                    0.645
# 37252                    0.645
# 37253                    0.645
# 37254                    0.645
#
# [470 rows x 59 columns]

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_cases",data=india_case)
plt.show()

# %%
india_last_5_days=india_case.tail()

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_cases",data=india_last_5_days)
plt.show()

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_tests",data=india_case)
plt.show()

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_tests",data=india_last_5_days)
plt.show()

# %%
brazil_case=covid[covid["location"]=="Brazil"]

# %%
brazil_case
# Out:
#       iso_code      continent location        date  total_cases  new_cases  \
# 11278      BRA  South America   Brazil  2020-02-26          1.0        1.0
# 11279      BRA  South America   Brazil  2020-02-27          1.0        0.0
# 11280      BRA  South America   Brazil  2020-02-28          1.0        0.0
# 11281      BRA  South America   Brazil  2020-02-29          2.0        1.0
# 11282      BRA  South America   Brazil  2020-03-01          2.0        0.0
# ...        ...            ...      ...         ...          ...        ...
# 11716      BRA  South America   Brazil  2021-05-09   15184790.0    38911.0
# 11717      BRA  South America   Brazil  2021-05-10   15209990.0    25200.0
# 11718      BRA  South America   Brazil  2021-05-11   15282705.0    72715.0
# 11719      BRA  South America   Brazil  2021-05-12   15359397.0    76692.0
# 11720      BRA  South America   Brazil  2021-05-13   15433989.0    74592.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 11278                 NaN           NaN         NaN                  NaN  ...
# 11279                 NaN           NaN         NaN                  NaN  ...
# 11280                 NaN           NaN         NaN                  NaN  ...
# 11281                 NaN           NaN         NaN                  NaN  ...
# 11282                 NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 11716           61411.429      422340.0      1024.0             2100.143  ...
# 11717           61494.429      423229.0       889.0             2086.714  ...
# 11718           60831.000      425540.0      2311.0             1993.143  ...
# 11719           61316.286      428034.0      2494.0             1947.857  ...
# 11720           61489.429      430417.0      2383.0             1924.000  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 11278       14103.452              3.4                177.961
# 11279       14103.452              3.4                177.961
# 11280       14103.452              3.4                177.961
# 11281       14103.452              3.4                177.961
# 11282       14103.452              3.4                177.961
# ...               ...              ...                    ...
# 11716       14103.452              3.4                177.961
# 11717       14103.452              3.4                177.961
# 11718       14103.452              3.4                177.961
# 11719       14103.452              3.4                177.961
# 11720       14103.452              3.4                177.961
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 11278                 8.11            10.1          17.9
# 11279                 8.11            10.1          17.9
# 11280                 8.11            10.1          17.9
# 11281                 8.11            10.1          17.9
# 11282                 8.11            10.1          17.9
# ...                    ...             ...           ...
# 11716                 8.11            10.1          17.9
# 11717                 8.11            10.1          17.9
# 11718                 8.11            10.1          17.9
# 11719                 8.11            10.1          17.9
# 11720                 8.11            10.1          17.9
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 11278                     NaN                         2.2            75.88
# 11279                     NaN                         2.2            75.88
# 11280                     NaN                         2.2            75.88
# 11281                     NaN                         2.2            75.88
# 11282                     NaN                         2.2            75.88
# ...                       ...                         ...              ...
# 11716                     NaN                         2.2            75.88
# 11717                     NaN                         2.2            75.88
# 11718                     NaN                         2.2            75.88
# 11719                     NaN                         2.2            75.88
# 11720                     NaN                         2.2            75.88
#
#        human_development_index
# 11278                    0.765
# 11279                    0.765
# 11280                    0.765
# 11281                    0.765
# 11282                    0.765
# ...                        ...
# 11716                    0.765
# 11717                    0.765
# 11718                    0.765
# 11719                    0.765
# 11720                    0.765
#
# [443 rows x 59 columns]

# %%
brazil_last_5_days=brazil_case.tail()

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_cases",data=brazil_last_5_days)
plt.show()

# %%
india_japan_china=covid[(covid["location"] =="India") | (covid["location"] =="China") | (covid["location"]=="Japan")]

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="location",y="total_cases",data=india_japan_china)
plt.show()

# %%
germany_spain=covid[(covid["location"] =="Germany") | (covid["location"] =="Spain")]

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="location",y="total_cases",data=germany_spain)
plt.show()

# %%
last_day_cases=covid[covid["date"]=="2021-05-13"]
last_day_cases
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 444         AFG      Asia  Afghanistan  2021-05-13      63045.0      327.0
# 900    OWID_AFR       NaN       Africa  2021-05-13    4666422.0     9443.0
# 1344        ALB    Europe      Albania  2021-05-13     131890.0       45.0
# 1788        DZA    Africa      Algeria  2021-05-13     124889.0      207.0
# 2226        AND    Europe      Andorra  2021-05-13      13470.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 87256       VNM      Asia      Vietnam  2021-05-13       3740.0       82.0
# 87784  OWID_WRL       NaN        World  2021-05-13  161176148.0   725275.0
# 88183       YEM      Asia        Yemen  2021-05-13       6507.0        9.0
# 88605       ZMB    Africa       Zambia  2021-05-13      92262.0       51.0
# 89025       ZWE    Africa     Zimbabwe  2021-05-13      38491.0       25.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 444               269.000        2721.0         8.0                8.143  ...
# 900              8331.857      125597.0       234.0              283.000  ...
# 1344               54.286        2426.0         3.0                2.857  ...
# 1788              202.286        3355.0         5.0                6.857  ...
# 2226               15.286         127.0         0.0                0.000  ...
# ...                   ...           ...         ...                  ...  ...
# 87256              92.857          35.0         0.0                0.000  ...
# 87784          729345.571     3344394.0     13135.0            12610.429  ...
# 88183              11.571        1278.0         1.0                1.857  ...
# 88605              45.143        1260.0         1.0                0.571  ...
# 89025              13.286        1582.0         3.0                1.000  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 444          1803.987              NaN                597.029
# 900               NaN              NaN                    NaN
# 1344        11803.431              1.1                304.195
# 1788        13913.839              0.5                278.364
# 2226              NaN              NaN                109.135
# ...               ...              ...                    ...
# 87256        6171.884              2.0                245.465
# 87784       15469.207             10.0                233.070
# 88183        1479.147             18.8                495.003
# 88605        3689.251             57.5                234.499
# 89025        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 444                   9.59             NaN           NaN
# 900                    NaN             NaN           NaN
# 1344                 10.08           7.100        51.200
# 1788                  6.73           0.700        30.400
# 2226                  7.97          29.000        37.800
# ...                    ...             ...           ...
# 87256                 6.00           1.000        45.900
# 87784                 8.51           6.434        34.635
# 88183                 5.35           7.600        29.200
# 88605                 3.94           3.100        24.700
# 89025                 1.82           1.600        30.700
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 444                    37.746                       0.500            64.83
# 900                       NaN                         NaN              NaN
# 1344                      NaN                       2.890            78.57
# 1788                   83.741                       1.900            76.88
# 2226                      NaN                         NaN            83.73
# ...                       ...                         ...              ...
# 87256                  85.847                       2.600            75.40
# 87784                  60.130                       2.705            72.58
# 88183                  49.542                       0.700            66.12
# 88605                  13.938                       2.000            63.89
# 89025                  36.791                       1.700            61.49
#
#        human_development_index
# 444                      0.511
# 900                        NaN
# 1344                     0.795
# 1788                     0.748
# 2226                     0.868
# ...                        ...
# 87256                    0.704
# 87784                    0.737
# 88183                    0.470
# 88605                    0.584
# 89025                    0.571
#
# [210 rows x 59 columns]

# %%
max_cases_country=last_day_cases.sort_values(by="total_cases",ascending=False)
max_cases_country
# Out:
#        iso_code      continent             location        date  total_cases  \
# 87784  OWID_WRL            NaN                World  2021-05-13  161176148.0
# 27151  OWID_EUR            NaN               Europe  2021-05-13   46139061.0
# 4613   OWID_ASI            NaN                 Asia  2021-05-13   45696137.0
# 59260  OWID_NAM            NaN        North America  2021-05-13   38243291.0
# 84732       USA  North America        United States  2021-05-13   32852871.0
# ...         ...            ...                  ...         ...          ...
# 35905       HKG           Asia            Hong Kong  2021-05-13          NaN
# 47570  OWID_LIC            NaN           Low income  2021-05-13          NaN
# 47689  OWID_LMC            NaN  Lower middle income  2021-05-13          NaN
# 48229       MAC           Asia                Macao  2021-05-13          NaN
# 84882  OWID_UMC            NaN  Upper middle income  2021-05-13          NaN
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 87784   725275.0          729345.571     3344394.0     13135.0
# 27151    93044.0           91894.429     1046837.0      2413.0
# 4613    430299.0          457936.571      591149.0      5465.0
# 59260    54772.0           51338.286      861435.0      1271.0
# 84732    38087.0           35384.000      584487.0       802.0
# ...          ...                 ...           ...         ...
# 35905        NaN                 NaN           NaN         NaN
# 47570        NaN                 NaN           NaN         NaN
# 47689        NaN                 NaN           NaN         NaN
# 48229        NaN                 NaN           NaN         NaN
# 84882        NaN                 NaN           NaN         NaN
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 87784            12610.429  ...       15469.207             10.0
# 27151             2243.714  ...             NaN              NaN
# 4613              5600.857  ...             NaN              NaN
# 59260             1052.571  ...             NaN              NaN
# 84732              619.857  ...       54225.446              1.2
# ...                    ...  ...             ...              ...
# 35905                  NaN  ...       56054.920              NaN
# 47570                  NaN  ...             NaN              NaN
# 47689                  NaN  ...             NaN              NaN
# 48229                  NaN  ...      104861.851              NaN
# 84882                  NaN  ...             NaN              NaN
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 87784                233.070                 8.51           6.434
# 27151                    NaN                  NaN             NaN
# 4613                     NaN                  NaN             NaN
# 59260                    NaN                  NaN             NaN
# 84732                151.089                10.79          19.100
# ...                      ...                  ...             ...
# 35905                    NaN                 8.33             NaN
# 47570                    NaN                  NaN             NaN
# 47689                    NaN                  NaN             NaN
# 48229                    NaN                  NaN             NaN
# 84882                    NaN                  NaN             NaN
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 87784        34.635                   60.13                       2.705
# 27151           NaN                     NaN                         NaN
# 4613            NaN                     NaN                         NaN
# 59260           NaN                     NaN                         NaN
# 84732        24.600                     NaN                       2.770
# ...             ...                     ...                         ...
# 35905           NaN                     NaN                         NaN
# 47570           NaN                     NaN                         NaN
# 47689           NaN                     NaN                         NaN
# 48229           NaN                     NaN                         NaN
# 84882           NaN                     NaN                         NaN
#
#        life_expectancy  human_development_index
# 87784            72.58                    0.737
# 27151              NaN                      NaN
# 4613               NaN                      NaN
# 59260              NaN                      NaN
# 84732            78.86                    0.926
# ...                ...                      ...
# 35905            84.86                    0.949
# 47570              NaN                      NaN
# 47689              NaN                      NaN
# 48229            84.24                      NaN
# 84882              NaN                      NaN
#
# [210 rows x 59 columns]

# %%
max_cases_country[1:6]
# Out:
#        iso_code      continent        location        date  total_cases  \
# 27151  OWID_EUR            NaN          Europe  2021-05-13   46139061.0
# 4613   OWID_ASI            NaN            Asia  2021-05-13   45696137.0
# 59260  OWID_NAM            NaN   North America  2021-05-13   38243291.0
# 84732       USA  North America   United States  2021-05-13   32852871.0
# 27628  OWID_EUN            NaN  European Union  2021-05-13   31780856.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 27151    93044.0           91894.429     1046837.0      2413.0
# 4613    430299.0          457936.571      591149.0      5465.0
# 59260    54772.0           51338.286      861435.0      1271.0
# 84732    38087.0           35384.000      584487.0       802.0
# 27628    73366.0           71380.857      709429.0      1599.0
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 27151             2243.714  ...             NaN              NaN
# 4613              5600.857  ...             NaN              NaN
# 59260             1052.571  ...             NaN              NaN
# 84732              619.857  ...       54225.446              1.2
# 27628             1512.429  ...             NaN              NaN
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 27151                    NaN                  NaN             NaN
# 4613                     NaN                  NaN             NaN
# 59260                    NaN                  NaN             NaN
# 84732                151.089                10.79            19.1
# 27628                    NaN                  NaN             NaN
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 27151           NaN                     NaN                         NaN
# 4613            NaN                     NaN                         NaN
# 59260           NaN                     NaN                         NaN
# 84732          24.6                     NaN                        2.77
# 27628           NaN                     NaN                         NaN
#
#        life_expectancy  human_development_index
# 27151              NaN                      NaN
# 4613               NaN                      NaN
# 59260              NaN                      NaN
# 84732            78.86                    0.926
# 27628              NaN                      NaN
#
# [5 rows x 59 columns]

# %%
sns.barplot(x="location",y="total_cases",data=max_cases_country[1:6],hue="location")
plt.show()

# %%
india_case.head()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 36785      IND      Asia    India  2020-01-30          1.0        1.0
# 36786      IND      Asia    India  2020-01-31          1.0        0.0
# 36787      IND      Asia    India  2020-02-01          1.0        0.0
# 36788      IND      Asia    India  2020-02-02          2.0        1.0
# 36789      IND      Asia    India  2020-02-03          3.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 36785                 NaN           NaN         NaN                  NaN  ...
# 36786                 NaN           NaN         NaN                  NaN  ...
# 36787                 NaN           NaN         NaN                  NaN  ...
# 36788                 NaN           NaN         NaN                  NaN  ...
# 36789                 NaN           NaN         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 36785        6426.674             21.2                 282.28
# 36786        6426.674             21.2                 282.28
# 36787        6426.674             21.2                 282.28
# 36788        6426.674             21.2                 282.28
# 36789        6426.674             21.2                 282.28
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 36785                10.39             1.9          20.6
# 36786                10.39             1.9          20.6
# 36787                10.39             1.9          20.6
# 36788                10.39             1.9          20.6
# 36789                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 36785                   59.55                        0.53            69.66
# 36786                   59.55                        0.53            69.66
# 36787                   59.55                        0.53            69.66
# 36788                   59.55                        0.53            69.66
# 36789                   59.55                        0.53            69.66
#
#        human_development_index
# 36785                    0.645
# 36786                    0.645
# 36787                    0.645
# 36788                    0.645
# 36789                    0.645
#
# [5 rows x 59 columns]

# %%
#Linear regression
from sklearn.model_selection import train_test_split

# %%
import datetime as dt
india_case['date'] = pd.to_datetime(india_case['date']) 
india_case.head()
# Out:
# <ipython-input-52-84b2f61bed3e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india_case['date'] = pd.to_datetime(india_case['date'])
#       iso_code continent location       date  total_cases  new_cases  \
# 36785      IND      Asia    India 2020-01-30          1.0        1.0
# 36786      IND      Asia    India 2020-01-31          1.0        0.0
# 36787      IND      Asia    India 2020-02-01          1.0        0.0
# 36788      IND      Asia    India 2020-02-02          2.0        1.0
# 36789      IND      Asia    India 2020-02-03          3.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 36785                 NaN           NaN         NaN                  NaN  ...
# 36786                 NaN           NaN         NaN                  NaN  ...
# 36787                 NaN           NaN         NaN                  NaN  ...
# 36788                 NaN           NaN         NaN                  NaN  ...
# 36789                 NaN           NaN         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 36785        6426.674             21.2                 282.28
# 36786        6426.674             21.2                 282.28
# 36787        6426.674             21.2                 282.28
# 36788        6426.674             21.2                 282.28
# 36789        6426.674             21.2                 282.28
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 36785                10.39             1.9          20.6
# 36786                10.39             1.9          20.6
# 36787                10.39             1.9          20.6
# 36788                10.39             1.9          20.6
# 36789                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 36785                   59.55                        0.53            69.66
# 36786                   59.55                        0.53            69.66
# 36787                   59.55                        0.53            69.66
# 36788                   59.55                        0.53            69.66
# 36789                   59.55                        0.53            69.66
#
#        human_development_index
# 36785                    0.645
# 36786                    0.645
# 36787                    0.645
# 36788                    0.645
# 36789                    0.645
#
# [5 rows x 59 columns]

# %%
india_case['date']=india_case['date'].map(dt.datetime.toordinal)
india_case.head()
# Out:
# <ipython-input-53-923c34e59a4e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india_case['date']=india_case['date'].map(dt.datetime.toordinal)
#       iso_code continent location    date  total_cases  new_cases  \
# 36785      IND      Asia    India  737454          1.0        1.0
# 36786      IND      Asia    India  737455          1.0        0.0
# 36787      IND      Asia    India  737456          1.0        0.0
# 36788      IND      Asia    India  737457          2.0        1.0
# 36789      IND      Asia    India  737458          3.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 36785                 NaN           NaN         NaN                  NaN  ...
# 36786                 NaN           NaN         NaN                  NaN  ...
# 36787                 NaN           NaN         NaN                  NaN  ...
# 36788                 NaN           NaN         NaN                  NaN  ...
# 36789                 NaN           NaN         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 36785        6426.674             21.2                 282.28
# 36786        6426.674             21.2                 282.28
# 36787        6426.674             21.2                 282.28
# 36788        6426.674             21.2                 282.28
# 36789        6426.674             21.2                 282.28
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 36785                10.39             1.9          20.6
# 36786                10.39             1.9          20.6
# 36787                10.39             1.9          20.6
# 36788                10.39             1.9          20.6
# 36789                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 36785                   59.55                        0.53            69.66
# 36786                   59.55                        0.53            69.66
# 36787                   59.55                        0.53            69.66
# 36788                   59.55                        0.53            69.66
# 36789                   59.55                        0.53            69.66
#
#        human_development_index
# 36785                    0.645
# 36786                    0.645
# 36787                    0.645
# 36788                    0.645
# 36789                    0.645
#
# [5 rows x 59 columns]

# %%
x=india_case['date']
y=india_case['total_cases']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
import numpy as np 
lr.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression()

# %%
india_case.tail()
# Out:
#       iso_code continent location    date  total_cases  new_cases  \
# 37250      IND      Asia    India  737919   22662575.0   366494.0
# 37251      IND      Asia    India  737920   22992517.0   329942.0
# 37252      IND      Asia    India  737921   23340938.0   348421.0
# 37253      IND      Asia    India  737922   23703665.0   362727.0
# 37254      IND      Asia    India  737923   24046809.0   343144.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 37250          391008.286      246116.0      3769.0             3879.571  ...
# 37251          387097.714      249992.0      3876.0             3940.571  ...
# 37252          382279.857      254197.0      4205.0             4001.286  ...
# 37253          375179.286      258317.0      4120.0             4021.286  ...
# 37254          365030.143      262317.0      4000.0             4033.429  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 37250        6426.674             21.2                 282.28
# 37251        6426.674             21.2                 282.28
# 37252        6426.674             21.2                 282.28
# 37253        6426.674             21.2                 282.28
# 37254        6426.674             21.2                 282.28
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 37250                10.39             1.9          20.6
# 37251                10.39             1.9          20.6
# 37252                10.39             1.9          20.6
# 37253                10.39             1.9          20.6
# 37254                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 37250                   59.55                        0.53            69.66
# 37251                   59.55                        0.53            69.66
# 37252                   59.55                        0.53            69.66
# 37253                   59.55                        0.53            69.66
# 37254                   59.55                        0.53            69.66
#
#        human_development_index
# 37250                    0.645
# 37251                    0.645
# 37252                    0.645
# 37253                    0.645
# 37254                    0.645
#
# [5 rows x 59 columns]

# %%
y_pred=lr.predict(np.array(x_test).reshape(-1,1))

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(x_test,y_pred)
# Out:
# 48651031849065.49

# %%
lr.predict(np.array([[737572]]))
# Out:
# array([[1409121.30047989]])
